# %% [markdown]
# <a href="https://colab.research.google.com/github/robajradi/files/blob/main/python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
y = 10
z = 3
x<y
x>z
x<y and x<z
x<y or x<z
not(x)
not(x) or y
not(x) or not(y)
not(x) and not(y)
# Out:
# False

# %%
x = 5
y = 10
z = 3
#x*=y # x=x*y
#x
(x**y%30)%(8//z) # (5**10%30)%(8//3) # (9765625%30)%(2) # (25)%(2)
not(x**y%30)%(8//z)or(x and y and z) # true
# Out:
# 3

# %%
num1=5
num2=10
if num1>num2:#false
  print('num1 is larger') #true
else:
  print('num2 is larger') #false


num1=50
num2=10
if num1>num2:#true
  print('num1 is larger') #true
else:
  print('num2 is larger') #false

num1=50
num2=50
if num1>num2:#false
  print('num1 is larger') #true
else:
  print('num2 is larger') #false هنا هل صح انه اختار الثانيه بالرون لا لانه غلط اصلا عشان كذا تحت كتبناه بشكل صحيح اننا حطينا الاثنين يساوون بعض

num1=50
num2=50
if num1>num2:#false
  print('num1 is larger') #true
elif num2>num1: #false
  print('num2 is larger') #false
else:
  print('both number are equal')

num1=30
num2=50
if num1>num2:#false
  print('num1 is larger') #true
elif num2>num1: #true
  print('num2 is larger') #false
else:
  print('both number are equal')
# Out:
# num2 is larger
# num1 is larger
# num2 is larger
# both number are equal
# num2 is larger

# %%
number=5 # هنا ابغى اعرف اذا الخمسة موجب او سالب
if number>0:
  print('the number is posetive')
else:
   print('the number is negative')

number=0 # هنا ابغى اعرف اذا الصفر موجب او سالب لكن طلع لي نيقتف وهذا غلط عشان كذا حطينا ال elif
if number>0:
  print('the number is posetive')
else:
   print('the number is negative')

number=0 # هنا ابغى اعرف اذا الصفر موجب او سالب وعشان الاجابة تطلع صح اضفنا elif
if number>0:
  print('the number is posetive')
elif number<5:
   print('the number is negative')
else:
  print('the number is zero')
# Out:
# the number is posetive
# the number is negative
# the number is negative

# %%
number=15 #هنا نبغى نعرف اذا الرقم هذا فردي ولا زوجي
if number % 2==0: #هنا ليه حطينا اليساوي مرتين عشان قاعدين نسال ونختبر مو قاعدين نعرف
  print('the number is even')
else:
  print('the number is odd')
# Out:
# the number is odd

# %%
number=float(input('please enter the number to be tested')) #هنا استخدمان الانبوت عشان اذا المستخدم استخدم رقم يطلع النتيجة اذا هي رقم زوجي او فردي وحطينا فلوت عشان مايطلع لنا غلط لانه دالة الانبوت تطلع اي شي سترنق واحنا نبغى رقم مع الكلام
if number % 2==0: #هنا ليه حطينا اليساوي مرتين عشان قاعدين نسال ونختبر مو قاعدين نعرف
  print('the number is even')
else:
  print('the number is odd')
# Out:
# please enter the number to be tested5
# the number is odd

# %% [markdown]
# question
#
# accept a grade from the user and we want to test it
# 90 -> A+
# 75, <90 -> A
# 50, <75 -> B
# <50> -> Fail

# %%
number=float(input('please enter the number to be tested'))
if number>=90:
  print('the grade is A+')
elif number>=75:
  print('the grade is A')
elif number>=50:
  print('the grade is B')
else:
  print('the grade is fail')
# Out:
# please enter the number to be tested40
# the grade is fail

# %% [markdown]
# الي تحت بيكون الجواب المثالي

# %%
check1=input('please enter your grade')
if check1.isnumeric(): # هنا عملت الاف الخارجية
  grade=float(check1)
#grade=float(input('please enter the grade to be tested'))
  if grade>100 or grade<0:
    print('invalid input, Please Re-enter a proper grade between 0 and 100')# هنا لو المستخدم حط اكبر من 100 اطلع له رسالة خطأ انه المفترض انك تحط رقم بين 0 و 100
  elif grade>=90:
    print('your grade is A+')
  elif grade>=75:
    print('your grade is A')
  elif grade>=50:
    print('your grade is B')
  else:# close if inner
    print('your grade is F')
else:# close if outer
  print('invalid value, Please Re-enter a proper grade only number')
# Out:
# please enter your grade85
# your grade is A
